# %%
# !pip --version
# Out:
# pip 24.0 from C:\Users\ms289\python\lib\site-packages\pip (python 3.10)

# %%
# !pip install pygame
# Out:
# ...
#    ---------------------------------------- 0.0/10.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/10.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/10.8 MB ? eta -:--:--
#    ---------------------------------------- 0.1/10.8 MB 837.8 kB/s eta 0:00:13
#    ---------------------------------------- 0.1/10.8 MB 837.8 kB/s eta 0:00:13
#    - -------------------------------------- 0.3/10.8 MB 1.4 MB/s eta 0:00:08
#    - -------------------------------------- 0.3/10.8 MB 1.4 MB/s eta 0:00:08
#    - -------------------------------------- 0.4/10.8 MB 1.2 MB/s eta 0:00:09
#    - -------------------------------------- 0.4/10.8 MB 1.2 MB/s eta 0:00:09
#    -- ------------------------------------- 0.6/10.8 MB 1.5 MB/s eta 0:00:07
#    -- ------------------------------------- 0.6/10.8 MB 1.5 MB/s eta 0:00:07
#    -- ------------------------------------- 0.6/10.8 MB 1.5 MB/s eta 0:00:07
# ...
